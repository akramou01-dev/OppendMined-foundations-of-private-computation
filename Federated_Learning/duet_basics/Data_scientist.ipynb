# %%
import syft as sy

# %% [markdown]
# on va d'abbord lancer duet dans le coté du data_ouwner pour avoir le clé qui va etre rentrer dans le coté du data_scientist pour avoir une connexion

# %%
duet = sy.join_duet("9ce843f3ecd63aec33cf2311b74d421f")
# Out:
# 🎤  🎸  ♪♪♪ Joining Duet ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently in beta.
# ♫♫♫ > Use at your own risk.
#
#
#     > ❤️ Love Duet? Please consider supporting our community!
#     > https://github.com/sponsors/OpenMined
#
# ♫♫♫ > Punching through firewall to OpenGrid Network Node at:
# ♫♫♫ > http://ec2-18-218-7-180.us-east-2.compute.amazonaws.com:5000
# ♫♫♫ >
# ♫♫♫ > ...waiting for response from OpenGrid Network...
# ♫♫♫ > DONE!
#
# ♫♫♫ > STEP 1: Send the following Duet Client ID to your duet partner!
# ♫♫♫ > Duet Client ID: f8ef1b6c1fc888788a02b5ea04370635
#
# ♫♫♫ > ...waiting for partner to connect...
#
# ♫♫♫ > CONNECTED!

# %% [markdown]
# on va mtn verifier si on a accés au donné ou nan

# %%
duet.store.pandas
# Out:
#                                         ID    Tags   Description  \
# 0  <UID: da6b4aa94fb74515b2135322784051e1>  [ages]  list of ages
#
#               object_type
# 0  <class 'torch.Tensor'>

# %%
#si le data_scientist a apprécier les donné alors il aura besoin d'un pointeur pour y acceder

data_pointer = duet.store[0]

# %%
avrg_age = data_pointer.float().mean()

# %%
duet.store

# %%
try: 
    avrg_age.get()
except Exception as e : 
    print(e)

# %%
#le datascientist a besoin de faire un request pour avoir le resultat

avrg_age.request(reason="Please approuve!")

# %%
#making another request

avrg_age.request(reason="i'm the data scientist and i have to check the avrg age")

# %%
duet.requests.pandas
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#apres l'acceptation du request 
avg = avrg_age.get()

# %%
avg
# Out:
# tensor(41.)

# %%
duet.torch
# Out:
# Module:
# 	.Tensor -> <syft.ast.klass.Class object at 0x000001D008AA6A60>
# 	.BFloat16Tensor -> <syft.ast.klass.Class object at 0x000001D008AA6AC0>
# 	.BoolTensor -> <syft.ast.klass.Class object at 0x000001D008AA6B20>
# 	.ByteTensor -> <syft.ast.klass.Class object at 0x000001D008AA6B80>
# 	.CharTensor -> <syft.ast.klass.Class object at 0x000001D008AA6BE0>
# 	.DoubleTensor -> <syft.ast.klass.Class object at 0x000001D008AA6C40>
# 	.FloatTensor -> <syft.ast.klass.Class object at 0x000001D008AA6CA0>
# 	.HalfTensor -> <syft.ast.klass.Class object at 0x000001D008AA6D00>
# 	.IntTensor -> <syft.ast.klass.Class object at 0x000001D008AA6D60>
# 	.LongTensor -> <syft.ast.klass.Class object at 0x000001D008AA6DC0>
# 	.ShortTensor -> <syft.ast.klass.Class object at 0x000001D008AA6E20>
# 	.nn -> Module:
# 		.Parameter -> <syft.ast.klass.Class object at 0x000001D008AA6F40>
# 		.Module -> <syft.ast.klass.Class object at 0x000001D008B74580>
# ...

# %%
max_age_ptr = data_pointer.float().amax()
min_age_ptr = data_pointer.float().amin()

# %%
max_age_result = max_age_ptr.get(
    request_block=True,
    reason="download the max of ages")
print(max_age_result)
# Out:
# tensor(100.)

# %%
min_age_result = min_age_ptr.get(
    request_block=True,
    reason="download the min of ages")
print(min_age_result)
# Out:
# tensor(12.)
